# %%
import numpy as np


def calculate(list):
    if len(list) != 9:
        raise ValueError("List must contain nine numbers.")
    else:
        matrix = np.array(list).reshape((3, 3))
        calculations = {
            'mean': [matrix.mean(axis=0).tolist(), matrix.mean(axis=1).tolist(), matrix.mean().tolist()],
            'variance': [matrix.var(axis=0).tolist(), matrix.var(axis=1).tolist(), matrix.var().tolist()],
            'standard deviation': [matrix.std(axis=0).tolist(), matrix.std(axis=1).tolist(), matrix.std().tolist()],
            'max': [matrix.max(axis=0).tolist(), matrix.max(axis=1).tolist(), matrix.max().tolist()],
            'min': [matrix.min(axis=0).tolist(), matrix.min(axis=1).tolist(), matrix.min().tolist()],
            'sum': [matrix.sum(axis=0).tolist(), matrix.sum(axis=1).tolist(), matrix.sum().tolist()]
            }
        return calculations

# %%
list = np.random.randint(1, 100, size=9)
print(list)
calculate(list)
# Out:
# [23 51 12  5 99 59 61 27 57]
# {'mean': [[29.666666666666668, 59.0, 42.666666666666664],
#   [28.666666666666668, 54.333333333333336, 48.333333333333336],
#   43.77777777777778],
#  'variance': [[544.8888888888888, 896.0, 470.8888888888889],
#   [269.55555555555554, 1483.5555555555554, 230.2222222222222],
#   781.283950617284],
#  'standard deviation': [[23.34285520001546,
#    29.93325909419153,
#    21.699974398346395],
#   [16.418147141366333, 38.5169515350781, 15.173075568988056],
#   27.951457039254393],
#  'max': [[61, 99, 59], [51, 99, 61], 99],
#  'min': [[5, 27, 12], [12, 5, 27], 5],
#  'sum': [[89, 177, 128], [86, 163, 145], 394]}
